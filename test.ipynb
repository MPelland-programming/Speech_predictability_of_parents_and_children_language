# %%
import re

# %%
re.sub(r'&\*\S*', '', 'when I was over at my friend’s house &*MOT:mhm the dog tried to lick me all over.')
# Out:
# 'when I was over at my friend’s house  the dog tried to lick me all over.'
