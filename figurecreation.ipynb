# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as spc

# %%
df = pd.read_csv('/home/hereinlies/Documents/Documents/Ecole/HEC/ProjetSupervise/data/Configs/NoContext1/new_model.csv')  # Replace 'data.csv' with your actual data file path

# %% [markdown]
# # Descriptive statistics

# %%
grouped = df.groupby('name').agg("first").reset_index()
gs = grouped.groupby("sex_child").agg({'sex_child': 'count'})
print("number of children: ", len(grouped))
print(gs.loc['female'])
print(gs.loc['male'])
# Out:
# number of children:  400
# sex_child    194
# Name: female, dtype: int64
# sex_child    204
# Name: male, dtype: int64

# %%
len(df)
# Out:
# 1850

# %%
ntrans_pparticipant = df["name"].value_counts()

fig, ax = plt.subplots(figsize=(6, 6))
ax.hist(ntrans_pparticipant, bins=20,log=True,color ='gray')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.set_xticks([0,60,120,180])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel("Nombre d'entrées de données",fontsize=14)
ax.set_ylabel('log(fréquence)',fontsize=14)

plt.show()

# %%
ntrans_pparticipant = df.groupby('name').count()

# %%
max(ntrans_pparticipant["age_diff"])
# Out:
# 180
